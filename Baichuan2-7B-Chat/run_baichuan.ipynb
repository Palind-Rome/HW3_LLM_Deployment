# %% [markdown]
# # Baichuan2-7B-Chat 部署与测试
#
# 按顺序执行以下单元格，并将运行成功和问答结果截图放入本目录的 `screenshots/`。

# %%
# %cd /mnt/workspace/HW3_LLM_Deployment

# %%
# !bash scripts/clone_models.sh baichuan

# %%
# !python Baichuan2-7B-Chat/run_baichuan.py
